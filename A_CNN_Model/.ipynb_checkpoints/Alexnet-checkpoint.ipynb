# %% [markdown]
# Convolutional Networks
#
# So far we have worked with deep fully-connected networks, using them to explore different optimization strategies and network architectures. Fully-connected networks are a good testbed for experimentation because they are very computationally efficient, but in practice all state-of-the-art results use convolutional networks instead.
#
# First you will implement several layer types that are used in convolutional networks. You will then use these layers to train a convolutional network on the CIFAR-10 dataset.

# %%
# As usual, a bit of setup
from select_image import *

import sys
sys.path.append('C:/Users/Marks-M3800/Documents/A2/assignment2')
sys.path.append('C:/Users/Marks-M3800/Documents/A_CNN_Model')
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.cnn import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient_array, eval_numerical_gradient
from cs231n.layers import *
from cs231n.fast_layers import *
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
  """ returns relative error """
  #print(np.maximum(1e-8, np.abs(x) + np.abs(y)))
  #print(np.abs(x - y))
  #print(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
  #print( np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y)))))
  return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))
# Out:
# run the following from the cs231n directory and try again:
# python setup.py build_ext --inplace
# You may also need to restart your iPython kernel

# %%
import os,random 
from select_image import Imagenet2017

Imagenet = Imagenet2017()

file_exists = os.path.isfile('covered_categories.txt')
if file_exists:
    os.remove('covered_categories.txt')

file = open('covered_categories.txt','w')
file.close()

cat_array = Imagenet.CategoryNumbers()
# Out:
# Generating File
# File Generated

# %%
image,xmin,ymin,xmax,ymax,category,class_num = Imagenet.imageselect()
plt.subplot(2,2,1)
plt.imshow(image.astype('uint8'))
plt.title('Original image')

bbox_image = Imagenet.BoundingBox(image,xmin,ymin,xmax,ymax)
cropped_image,rows,columns = Imagenet.CroppedImage(image,xmin,ymin,xmax,ymax)
scaled_image = Imagenet.ScaleImage226(image,xmin,ymin,xmax,ymax,rows,columns)

# Show the original image

plt.subplot(2,2,2)
plt.imshow(bbox_image.astype('uint8'))
plt.title('Image with Bounding Box image')
plt.subplot(2,2,3)
plt.imshow(cropped_image.astype('uint8'))
plt.title('Cropped image')
plt.subplot(2,2,4)
plt.imshow(scaled_image.astype('uint8'))
plt.title('Scaled image')

# %%
from alexnet import AlexNet

image_size = 227

std = 1e-2
model = AlexNet(input_dim=(3,image_size,image_size), hidden_dim=4096, num_classes=1000, weight_scale=std)


print ('Testing initialization ... ')
W1_std = abs(model.params['W1'].std() - std)
print(model.params['W1'].std())
#print('W1_std = ', W1_std)
#print('W1 = ', model.params['W1'])
b1 = model.params['b1']
W2_std = abs(model.params['W2'].std() - std)
b2 = model.params['b2']
assert W1_std < std / 10, 'First layer weights do not seem right'
assert np.all(b1 == 0), 'First layer biases do not seem right'
assert W2_std < std / 10, 'Second layer weights do not seem right'
assert np.all(b2 == 0), 'Second layer biases do not seem right'

X = np.ones((1,3,image_size,image_size))
print(X.shape)
print(scaled_image.shape)
X[0] = np.transpose(scaled_image, [2,0,1])


scores = model.loss(X)
print('scores shape = ', scores.shape)

filename, foldername = Imagenet.FileInfo()
print(filename)
print(foldername)

#y = np.asarray([foldername])
y = np.asarray([class_num])
loss, grads = model.loss(X, y)
print('loss = ', loss)

# %%
from validation_data import ValidationData

ValData = ValidationData()


image,xmin,ymin,xmax,ymax,category,class_num = ValData.image_select()
plt.subplot(2,2,1)
plt.imshow(image.astype('uint8'))
plt.title('Original image')

bbox_image = ValData.BoundingBox(image,xmin,ymin,xmax,ymax)
cropped_image,rows,columns = ValData.CroppedImage(image,xmin,ymin,xmax,ymax)
scaled_image = ValData.ScaleImage226(image,xmin,ymin,xmax,ymax,rows,columns)

# Show the original image
plt.subplot(2,2,2)
plt.imshow(bbox_image.astype('uint8'))
plt.title('Image with Bounding Box image')
plt.subplot(2,2,3)
plt.imshow(cropped_image.astype('uint8'))
plt.title('Cropped image')
plt.subplot(2,2,4)
plt.imshow(scaled_image.astype('uint8'))
plt.title('Scaled image')
# Out:
# C:\Users\Marks-M3800\Documents\A_CNN_Model\validation_data.py:257: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   temp_image = refreshed_image[ymin:ymax,xmin:xmax,:]

# %%
from TrainNet import TrainNet

Train_Net = TrainNet()

x_train, y_train = Train_Net.get_train_data(num_train=100)
x_val, y_val = Train_Net.get_val_data(num_val=1000)
# Out:
# Training Image:  0
# C:\Users\Marks-M3800\Documents\A_CNN_Model\select_image.py:273: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   temp_image = refreshed_image[ymin:ymax,xmin:xmax,:]
# Training Image:  1
# Training Image:  2
# Training Image:  3
# Training Image:  4
# Training Image:  5
# Training Image:  6
# Training Image:  7
# Training Image:  8
# Training Image:  9
# Training Image:  10
# Training Image:  11
# Training Image:  12
# Training Image:  13
# Training Image:  14
# Training Image:  15
# Training Image:  16
# Training Image:  17
# Training Image:  18
# Training Image:  19
# Training Image:  20
# Training Image:  21
# Training Image:  22
# Training Image:  23
# Training Image:  24
# Training Image:  25
# Training Image:  26
# Training Image:  27
# Training Image:  28
# Training Image:  29
# Training Image:  30
# Training Image:  31
# Training Image:  32
# Training Image:  33
# Training Image:  34
# Training Image:  35
# Training Image:  36
# Training Image:  37
# Training Image:  38
# Training Image:  39
# Training Image:  40
# Training Image:  41
# Training Image:  42
# Training Image:  43
# Training Image:  44
# Training Image:  45
# Training Image:  46
# Training Image:  47
# Training Image:  48
# Training Image:  49
# Training Image:  50
# Training Image:  51
# Training Image:  52
# Training Image:  53
# Training Image:  54
# Training Image:  55
# Training Image:  56
# Training Image:  57
# Training Image:  58
# Training Image:  59
# Training Image:  60
# Training Image:  61
# Training Image:  62
# Training Image:  63
# Training Image:  64
# Training Image:  65
# Training Image:  66
# Training Image:  67
# Training Image:  68
# Training Image:  69
# Training Image:  70
# Training Image:  71
# Training Image:  72
# Training Image:  73
# Training Image:  74
# Training Image:  75
# Training Image:  76
# Training Image:  77
# Training Image:  78
# Training Image:  79
# Training Image:  80
# Training Image:  81
# Training Image:  82
# Training Image:  83
# Training Image:  84
# Training Image:  85
# Training Image:  86
# Training Image:  87
# Training Image:  88
# Training Image:  89
# Training Image:  90
# Training Image:  91
# Training Image:  92
# Training Image:  93
# Training Image:  94
# Training Image:  95
# Training Image:  96
# Training Image:  97
# Training Image:  98
# Training Image:  99
# Validation Image:  0
# C:\Users\Marks-M3800\Documents\A_CNN_Model\validation_data.py:257: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   temp_image = refreshed_image[ymin:ymax,xmin:xmax,:]
# Validation Image:  1
# Validation Image:  2
# Validation Image:  3
# Validation Image:  4
# Validation Image:  5
# Validation Image:  6
# Validation Image:  7
# Validation Image:  8
# Validation Image:  9
# Validation Image:  10
# Validation Image:  11
# Validation Image:  12
# Validation Image:  13
# Validation Image:  14
# Validation Image:  15
# Validation Image:  16
# Validation Image:  17
# Validation Image:  18
# Validation Image:  19
# Validation Image:  20
# Validation Image:  21
# Validation Image:  22
# Validation Image:  23
# Validation Image:  24
# Validation Image:  25
# Validation Image:  26
# Validation Image:  27
# Validation Image:  28
# Validation Image:  29
# Validation Image:  30
# Validation Image:  31
# Validation Image:  32
# Validation Image:  33
# Validation Image:  34
# Validation Image:  35
# Validation Image:  36
# Validation Image:  37
# Validation Image:  38
# Validation Image:  39
# Validation Image:  40
# Validation Image:  41
# Validation Image:  42
# Validation Image:  43
# Validation Image:  44
# Validation Image:  45
# Validation Image:  46
# Validation Image:  47
# Validation Image:  48
# Validation Image:  49
# Validation Image:  50
# Validation Image:  51
# Validation Image:  52
# Validation Image:  53
# Validation Image:  54
# Validation Image:  55
# Validation Image:  56
# Validation Image:  57
# Validation Image:  58
# Validation Image:  59
# Validation Image:  60
# Validation Image:  61
# Validation Image:  62
# Validation Image:  63
# Validation Image:  64
# Validation Image:  65
# Validation Image:  66
# Validation Image:  67
# Validation Image:  68
# Validation Image:  69
# Validation Image:  70
# Validation Image:  71
# Validation Image:  72
# Validation Image:  73
# Validation Image:  74
# Validation Image:  75
# Validation Image:  76
# Validation Image:  77
# Validation Image:  78
# Validation Image:  79
# Validation Image:  80
# Validation Image:  81
# Validation Image:  82
# Validation Image:  83
# Validation Image:  84
# Validation Image:  85
# Validation Image:  86
# Validation Image:  87
# Validation Image:  88
# Validation Image:  89
# Validation Image:  90
# Validation Image:  91
# Validation Image:  92
# Validation Image:  93
# Validation Image:  94
# Validation Image:  95
# Validation Image:  96
# Validation Image:  97
# Validation Image:  98
# Validation Image:  99
# Validation Image:  100
# Validation Image:  101
# Validation Image:  102
# Validation Image:  103
# Validation Image:  104
# Validation Image:  105
# Validation Image:  106
# Validation Image:  107
# Validation Image:  108
# Validation Image:  109
# Validation Image:  110
# Validation Image:  111
# Validation Image:  112
# Validation Image:  113
# Validation Image:  114
# Validation Image:  115
# Validation Image:  116
# Validation Image:  117
# Validation Image:  118
# Validation Image:  119
# Validation Image:  120
# Validation Image:  121
# Validation Image:  122
# Validation Image:  123
# Validation Image:  124
# Validation Image:  125
# Validation Image:  126
# Validation Image:  127
# Validation Image:  128
# Validation Image:  129
# Validation Image:  130
# Validation Image:  131
# Validation Image:  132
# Validation Image:  133
# Validation Image:  134
# Validation Image:  135
# Validation Image:  136
# Validation Image:  137
# Validation Image:  138
# Validation Image:  139
# Validation Image:  140
# Validation Image:  141
# Validation Image:  142
# Validation Image:  143
# Validation Image:  144
# Validation Image:  145
# Validation Image:  146
# Validation Image:  147
# Validation Image:  148
# Validation Image:  149
# Validation Image:  150
# Validation Image:  151
# Validation Image:  152
# Validation Image:  153
# Validation Image:  154
# Validation Image:  155
# Validation Image:  156
# Validation Image:  157
# Validation Image:  158
# Validation Image:  159
# Validation Image:  160
# Validation Image:  161
# Validation Image:  162
# Validation Image:  163
# Validation Image:  164
# Validation Image:  165
# Validation Image:  166
# Validation Image:  167
# Validation Image:  168
# Validation Image:  169
# Validation Image:  170
# Validation Image:  171
# Validation Image:  172
# Validation Image:  173
# Validation Image:  174
# Validation Image:  175
# Validation Image:  176
# Validation Image:  177
# Validation Image:  178
# Validation Image:  179
# Validation Image:  180
# Validation Image:  181
# Validation Image:  182
# Validation Image:  183
# Validation Image:  184
# Validation Image:  185
# Validation Image:  186
# Validation Image:  187
# Validation Image:  188
# Validation Image:  189
# Validation Image:  190
# Validation Image:  191
# Validation Image:  192
# Validation Image:  193
# Validation Image:  194
# Validation Image:  195
# Validation Image:  196
# Validation Image:  197
# Validation Image:  198
# Validation Image:  199
# Validation Image:  200
# Validation Image:  201
# Validation Image:  202
# Validation Image:  203
# Validation Image:  204
# Validation Image:  205
# Validation Image:  206
# Validation Image:  207
# Validation Image:  208
# Validation Image:  209
# Validation Image:  210
# Validation Image:  211
# Validation Image:  212
# Validation Image:  213
# Validation Image:  214
# Validation Image:  215
# Validation Image:  216
# Validation Image:  217
# Validation Image:  218
# Validation Image:  219
# Validation Image:  220
# Validation Image:  221
# Validation Image:  222
# Validation Image:  223
# Validation Image:  224
# Validation Image:  225
# Validation Image:  226
# Validation Image:  227
# Validation Image:  228
# Validation Image:  229
# Validation Image:  230
# Validation Image:  231
# Validation Image:  232
# Validation Image:  233
# Validation Image:  234
# Validation Image:  235
# Validation Image:  236
# Validation Image:  237
# Validation Image:  238
# Validation Image:  239
# Validation Image:  240
# Validation Image:  241
# Validation Image:  242
# Validation Image:  243
# Validation Image:  244
# Validation Image:  245
# Validation Image:  246
# Validation Image:  247
# Validation Image:  248
# Validation Image:  249
# Validation Image:  250
# Validation Image:  251
# Validation Image:  252
# Validation Image:  253
# Validation Image:  254
# Validation Image:  255
# Validation Image:  256
# Validation Image:  257
# Validation Image:  258
# Validation Image:  259
# Validation Image:  260
# Validation Image:  261
# Validation Image:  262
# Validation Image:  263
# Validation Image:  264
# Validation Image:  265
# Validation Image:  266
# Validation Image:  267
# Validation Image:  268
# Validation Image:  269
# Validation Image:  270
# Validation Image:  271
# Validation Image:  272
# Validation Image:  273
# Validation Image:  274
# Validation Image:  275
# Validation Image:  276
# Validation Image:  277
# Validation Image:  278
# Validation Image:  279
# Validation Image:  280
# Validation Image:  281
# Validation Image:  282
# Validation Image:  283
# Validation Image:  284
# Validation Image:  285
# Validation Image:  286
# Validation Image:  287
# Validation Image:  288
# Validation Image:  289
# Validation Image:  290
# Validation Image:  291
# Validation Image:  292
# Validation Image:  293
# Validation Image:  294
# Validation Image:  295
# Validation Image:  296
# Validation Image:  297
# Validation Image:  298
# Validation Image:  299
# Validation Image:  300
# Validation Image:  301
# Validation Image:  302
# Validation Image:  303
# Validation Image:  304
# Validation Image:  305
# Validation Image:  306
# Validation Image:  307
# Validation Image:  308
# Validation Image:  309
# Validation Image:  310
# Validation Image:  311
# Validation Image:  312
# Validation Image:  313
# Validation Image:  314
# Validation Image:  315
# Validation Image:  316
# Validation Image:  317
# Validation Image:  318
# Validation Image:  319
# Validation Image:  320
# Validation Image:  321
# Validation Image:  322
# Validation Image:  323
# Validation Image:  324
# Validation Image:  325
# Validation Image:  326
# Validation Image:  327
# Validation Image:  328
# Validation Image:  329
# Validation Image:  330
# Validation Image:  331
# Validation Image:  332
# Validation Image:  333
# Validation Image:  334
# Validation Image:  335
# Validation Image:  336
# Validation Image:  337
# Validation Image:  338
# Validation Image:  339
# Validation Image:  340
# Validation Image:  341
# Validation Image:  342
# Validation Image:  343
# Validation Image:  344
# Validation Image:  345
# Validation Image:  346
# Validation Image:  347
# Validation Image:  348
# Validation Image:  349
# Validation Image:  350
# Validation Image:  351
# Validation Image:  352
# Validation Image:  353
# Validation Image:  354
# Validation Image:  355
# Validation Image:  356
# Validation Image:  357
# Validation Image:  358
# Validation Image:  359
# Validation Image:  360
# Validation Image:  361
# Validation Image:  362
# Validation Image:  363
# Validation Image:  364
# Validation Image:  365
# Validation Image:  366
# Validation Image:  367
# Validation Image:  368
# Validation Image:  369
# Validation Image:  370
# Validation Image:  371
# Validation Image:  372
# Validation Image:  373
# Validation Image:  374
# Validation Image:  375
# Validation Image:  376
# Validation Image:  377
# Validation Image:  378
# Validation Image:  379
# Validation Image:  380
# Validation Image:  381
# Validation Image:  382
# Validation Image:  383
# Validation Image:  384
# Validation Image:  385
# Validation Image:  386
# Validation Image:  387
# Validation Image:  388
# Validation Image:  389
# Validation Image:  390
# Validation Image:  391
# Validation Image:  392
# Validation Image:  393
# Validation Image:  394
# Validation Image:  395
# Validation Image:  396
# Validation Image:  397
# Validation Image:  398
# Validation Image:  399
# Validation Image:  400
# Validation Image:  401
# Validation Image:  402
# Validation Image:  403
# Validation Image:  404
# Validation Image:  405
# Validation Image:  406
# Validation Image:  407
# Validation Image:  408
# Validation Image:  409
# Validation Image:  410
# Validation Image:  411
# Validation Image:  412
# Validation Image:  413
# Validation Image:  414
# Validation Image:  415
# Validation Image:  416
# Validation Image:  417
# Validation Image:  418
# Validation Image:  419
# Validation Image:  420
# Validation Image:  421
# Validation Image:  422
# Validation Image:  423
# Validation Image:  424
# Validation Image:  425
# Validation Image:  426
# Validation Image:  427
# Validation Image:  428
# Validation Image:  429
# Validation Image:  430
# Validation Image:  431
# Validation Image:  432
# Validation Image:  433
# Validation Image:  434
# Validation Image:  435
# Validation Image:  436
# Validation Image:  437
# Validation Image:  438
# Validation Image:  439
# Validation Image:  440
# Validation Image:  441
# Validation Image:  442
# Validation Image:  443
# Validation Image:  444
# Validation Image:  445
# Validation Image:  446
# Validation Image:  447
# Validation Image:  448
# Validation Image:  449
# Validation Image:  450
# Validation Image:  451
# Validation Image:  452
# Validation Image:  453
# Validation Image:  454
# Validation Image:  455
# Validation Image:  456
# Validation Image:  457
# Validation Image:  458
# Validation Image:  459
# Validation Image:  460
# Validation Image:  461
# Validation Image:  462
# Validation Image:  463
# Validation Image:  464
# Validation Image:  465
# Validation Image:  466
# Validation Image:  467
# Validation Image:  468
# Validation Image:  469
# Validation Image:  470
# Validation Image:  471
# Validation Image:  472
# Validation Image:  473
# Validation Image:  474
# Validation Image:  475
# Validation Image:  476
# Validation Image:  477
# Validation Image:  478
# Validation Image:  479
# Validation Image:  480
# Validation Image:  481
# Validation Image:  482
# Validation Image:  483
# Validation Image:  484
# Validation Image:  485
# Validation Image:  486
# Validation Image:  487
# Validation Image:  488
# Validation Image:  489
# Validation Image:  490
# Validation Image:  491
# Validation Image:  492
# Validation Image:  493
# Validation Image:  494
# Validation Image:  495
# Validation Image:  496
# Validation Image:  497
# Validation Image:  498
# Validation Image:  499
# Validation Image:  500
# Validation Image:  501
# Validation Image:  502
# Validation Image:  503
# Validation Image:  504
# Validation Image:  505
# Validation Image:  506
# Validation Image:  507
# Validation Image:  508
# Validation Image:  509
# Validation Image:  510
# Validation Image:  511
# Validation Image:  512
# Validation Image:  513
# Validation Image:  514
# Validation Image:  515
# Validation Image:  516
# Validation Image:  517
# Validation Image:  518
# Validation Image:  519
# Validation Image:  520
# Validation Image:  521
# Validation Image:  522
# Validation Image:  523
# Validation Image:  524
# Validation Image:  525
# Validation Image:  526
# Validation Image:  527
# Validation Image:  528
# Validation Image:  529
# Validation Image:  530
# Validation Image:  531
# Validation Image:  532
# Validation Image:  533
# Validation Image:  534
# Validation Image:  535
# Validation Image:  536
# Validation Image:  537
# Validation Image:  538
# Validation Image:  539
# Validation Image:  540
# Validation Image:  541
# Validation Image:  542
# Validation Image:  543
# Validation Image:  544
# Validation Image:  545
# Validation Image:  546
# Validation Image:  547
# Validation Image:  548
# Validation Image:  549
# Validation Image:  550
# Validation Image:  551
# Validation Image:  552
# Validation Image:  553
# Validation Image:  554
# Validation Image:  555
# Validation Image:  556
# Validation Image:  557
# Validation Image:  558
# Validation Image:  559
# Validation Image:  560
# Validation Image:  561
# Validation Image:  562
# Validation Image:  563
# Validation Image:  564
# Validation Image:  565
# Validation Image:  566
# Validation Image:  567
# Validation Image:  568
# Validation Image:  569
# Validation Image:  570
# Validation Image:  571
# Validation Image:  572
# Validation Image:  573
# Validation Image:  574
# Validation Image:  575
# Validation Image:  576
# Validation Image:  577
# Validation Image:  578
# Validation Image:  579
# Validation Image:  580
# Validation Image:  581
# Validation Image:  582
# Validation Image:  583
# Validation Image:  584
# Validation Image:  585
# Validation Image:  586
# Validation Image:  587
# Validation Image:  588
# Validation Image:  589
# Validation Image:  590
# Validation Image:  591
# Validation Image:  592
# Validation Image:  593
# Validation Image:  594
# Validation Image:  595
# Validation Image:  596
# Validation Image:  597
# Validation Image:  598
# Validation Image:  599
# Validation Image:  600
# Validation Image:  601
# Validation Image:  602
# Validation Image:  603
# Validation Image:  604
# Validation Image:  605
# Validation Image:  606
# Validation Image:  607
# Validation Image:  608
# Validation Image:  609
# Validation Image:  610
# Validation Image:  611
# Validation Image:  612
# Validation Image:  613
# Validation Image:  614
# Validation Image:  615
# Validation Image:  616
# Validation Image:  617
# Validation Image:  618
# Validation Image:  619
# Validation Image:  620
# Validation Image:  621
# Validation Image:  622
# Validation Image:  623
# Validation Image:  624
# Validation Image:  625
# Validation Image:  626
# Validation Image:  627
# Validation Image:  628
# Validation Image:  629
# Validation Image:  630
# Validation Image:  631
# Validation Image:  632
# Validation Image:  633
# Validation Image:  634
# Validation Image:  635
# Validation Image:  636
# Validation Image:  637
# Validation Image:  638
# Validation Image:  639
# Validation Image:  640
# Validation Image:  641
# Validation Image:  642
# Validation Image:  643
# Validation Image:  644
# Validation Image:  645
# Validation Image:  646
# Validation Image:  647
# Validation Image:  648
# Validation Image:  649
# Validation Image:  650
# Validation Image:  651
# Validation Image:  652
# Validation Image:  653
# Validation Image:  654
# Validation Image:  655
# Validation Image:  656
# Validation Image:  657
# Validation Image:  658
# Validation Image:  659
# Validation Image:  660
# Validation Image:  661
# Validation Image:  662
# Validation Image:  663
# Validation Image:  664
# Validation Image:  665
# Validation Image:  666
# Validation Image:  667
# Validation Image:  668
# Validation Image:  669
# Validation Image:  670
# Validation Image:  671
# Validation Image:  672
# Validation Image:  673
# Validation Image:  674
# Validation Image:  675
# Validation Image:  676
# Validation Image:  677
# Validation Image:  678
# Validation Image:  679
# Validation Image:  680
# Validation Image:  681
# Validation Image:  682
# Validation Image:  683
# Validation Image:  684
# Validation Image:  685
# Validation Image:  686
# Validation Image:  687
# Validation Image:  688
# Validation Image:  689
# Validation Image:  690
# Validation Image:  691
# Validation Image:  692
# Validation Image:  693
# Validation Image:  694
# Validation Image:  695
# Validation Image:  696
# Validation Image:  697
# Validation Image:  698
# Validation Image:  699
# Validation Image:  700
# Validation Image:  701
# Validation Image:  702
# Validation Image:  703
# Validation Image:  704
# Validation Image:  705
# Validation Image:  706
# Validation Image:  707
# Validation Image:  708
# Validation Image:  709
# Validation Image:  710
# Validation Image:  711
# Validation Image:  712
# Validation Image:  713
# Validation Image:  714
# Validation Image:  715
# Validation Image:  716
# Validation Image:  717
# Validation Image:  718
# Validation Image:  719
# Validation Image:  720
# Validation Image:  721
# Validation Image:  722
# Validation Image:  723
# Validation Image:  724
# Validation Image:  725
# Validation Image:  726
# Validation Image:  727
# Validation Image:  728
# Validation Image:  729
# Validation Image:  730
# Validation Image:  731
# Validation Image:  732
# Validation Image:  733
# Validation Image:  734
# Validation Image:  735
# Validation Image:  736
# Validation Image:  737
# Validation Image:  738
# Validation Image:  739
# Validation Image:  740
# Validation Image:  741
# Validation Image:  742
# Validation Image:  743
# Validation Image:  744
# Validation Image:  745
# Validation Image:  746
# Validation Image:  747
# Validation Image:  748
# Validation Image:  749
# Validation Image:  750
# Validation Image:  751
# Validation Image:  752
# Validation Image:  753
# Validation Image:  754
# Validation Image:  755
# Validation Image:  756
# Validation Image:  757
# Validation Image:  758
# Validation Image:  759
# Validation Image:  760
# Validation Image:  761
# Validation Image:  762
# Validation Image:  763
# Validation Image:  764
# Validation Image:  765
# Validation Image:  766
# Validation Image:  767
# Validation Image:  768
# Validation Image:  769
# Validation Image:  770
# Validation Image:  771
# Validation Image:  772
# Validation Image:  773
# Validation Image:  774
# Validation Image:  775
# Validation Image:  776
# Validation Image:  777
# Validation Image:  778
# Validation Image:  779
# Validation Image:  780
# Validation Image:  781
# Validation Image:  782
# Validation Image:  783
# Validation Image:  784
# Validation Image:  785
# Validation Image:  786
# Validation Image:  787
# Validation Image:  788
# Validation Image:  789
# Validation Image:  790
# Validation Image:  791
# Validation Image:  792
# Validation Image:  793
# Validation Image:  794
# Validation Image:  795
# Validation Image:  796
# Validation Image:  797
# Validation Image:  798
# Validation Image:  799
# Validation Image:  800
# Validation Image:  801
# Validation Image:  802
# Validation Image:  803
# Validation Image:  804
# Validation Image:  805
# Validation Image:  806
# Validation Image:  807
# Validation Image:  808
# Validation Image:  809
# Validation Image:  810
# Validation Image:  811
# Validation Image:  812
# Validation Image:  813
# Validation Image:  814
# Validation Image:  815
# Validation Image:  816
# Validation Image:  817
# Validation Image:  818
# Validation Image:  819
# Validation Image:  820
# Validation Image:  821
# Validation Image:  822
# Validation Image:  823
# Validation Image:  824
# Validation Image:  825
# Validation Image:  826
# Validation Image:  827
# Validation Image:  828
# Validation Image:  829
# Validation Image:  830
# Validation Image:  831
# Validation Image:  832
# Validation Image:  833
# Validation Image:  834
# Validation Image:  835
# Validation Image:  836
# Validation Image:  837
# Validation Image:  838
# Validation Image:  839
# Validation Image:  840
# Validation Image:  841
# Validation Image:  842
# Validation Image:  843
# Validation Image:  844
# Validation Image:  845
# Validation Image:  846
# Validation Image:  847
# Validation Image:  848
# Validation Image:  849
# Validation Image:  850
# Validation Image:  851
# Validation Image:  852
# Validation Image:  853
# Validation Image:  854
# Validation Image:  855
# Validation Image:  856
# Validation Image:  857
# Validation Image:  858
# Validation Image:  859
# Validation Image:  860
# Validation Image:  861
# Validation Image:  862
# Validation Image:  863
# Validation Image:  864
# Validation Image:  865
# Validation Image:  866
# Validation Image:  867
# Validation Image:  868
# Validation Image:  869
# Validation Image:  870
# Validation Image:  871
# Validation Image:  872
# Validation Image:  873
# Validation Image:  874
# Validation Image:  875
# Validation Image:  876
# Validation Image:  877
# Validation Image:  878
# Validation Image:  879
# Validation Image:  880
# Validation Image:  881
# Validation Image:  882
# Validation Image:  883
# Validation Image:  884
# Validation Image:  885
# Validation Image:  886
# Validation Image:  887
# Validation Image:  888
# Validation Image:  889
# Validation Image:  890
# Validation Image:  891
# Validation Image:  892
# Validation Image:  893
# Validation Image:  894
# Validation Image:  895
# Validation Image:  896
# Validation Image:  897
# Validation Image:  898
# Validation Image:  899
# Validation Image:  900
# Validation Image:  901
# Validation Image:  902
# Validation Image:  903
# Validation Image:  904
# Validation Image:  905
# Validation Image:  906
# Validation Image:  907
# Validation Image:  908
# Validation Image:  909
# Validation Image:  910
# Validation Image:  911
# Validation Image:  912
# Validation Image:  913
# Validation Image:  914
# Validation Image:  915
# Validation Image:  916
# Validation Image:  917
# Validation Image:  918
# Validation Image:  919
# Validation Image:  920
# Validation Image:  921
# Validation Image:  922
# Validation Image:  923
# Validation Image:  924
# Validation Image:  925
# Validation Image:  926
# Validation Image:  927
# Validation Image:  928
# Validation Image:  929
# Validation Image:  930
# Validation Image:  931
# Validation Image:  932
# Validation Image:  933
# Validation Image:  934
# Validation Image:  935
# Validation Image:  936
# Validation Image:  937
# Validation Image:  938
# Validation Image:  939
# Validation Image:  940
# Validation Image:  941
# Validation Image:  942
# Validation Image:  943
# Validation Image:  944
# Validation Image:  945
# Validation Image:  946
# Validation Image:  947
# Validation Image:  948
# Validation Image:  949
# Validation Image:  950
# Validation Image:  951
# Validation Image:  952
# Validation Image:  953
# Validation Image:  954
# Validation Image:  955
# Validation Image:  956
# Validation Image:  957
# Validation Image:  958
# Validation Image:  959
# Validation Image:  960
# Validation Image:  961
# Validation Image:  962
# Validation Image:  963
# Validation Image:  964
# Validation Image:  965
# Validation Image:  966
# Validation Image:  967
# Validation Image:  968
# Validation Image:  969
# Validation Image:  970
# Validation Image:  971
# Validation Image:  972
# Validation Image:  973
# Validation Image:  974
# Validation Image:  975
# Validation Image:  976
# Validation Image:  977
# Validation Image:  978
# Validation Image:  979
# Validation Image:  980
# Validation Image:  981
# Validation Image:  982
# Validation Image:  983
# Validation Image:  984
# Validation Image:  985
# Validation Image:  986
# Validation Image:  987
# Validation Image:  988
# Validation Image:  989
# Validation Image:  990
# Validation Image:  991
# Validation Image:  992
# Validation Image:  993
# Validation Image:  994
# Validation Image:  995
# Validation Image:  996
# Validation Image:  997
# Validation Image:  998
# Validation Image:  999

# %%
from alexnet import AlexNet

image_size = 227

std = 1e-2
model = AlexNet()

x_train = np.transpose(x_train, [0,3,1,2])
print(x_train.shape)
x_val = np.transpose(x_val, [0,3,1,2])

num_train = 100
small_data = {
  'X_train': x_train,
  'y_train': y_train,
  'X_val': x_val,
  'y_val': y_val,
}

solver = Solver(model, small_data,
                num_epochs=10, batch_size=50,
                update_rule='adam',
                optim_config={
                  'learning_rate': 1e-3,
                },
                verbose=True, print_every=1)
solver.train()
# Out:
# (100, 3, 227, 227)
# SOLVER train
# SOLVER _step
# AlexNet Forward Pass Done
# C:\Users\Marks-M3800\Documents\A_CNN_Model\alexnet.py:156: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   Py[i] = P[y[i],i]
# loss =  6.90775527785
# Backprop Affine3
# Backprop Affine2
# Backprop Affine1
# C:\Users\Marks-M3800\Documents\A_CNN_Model\alexnet.py:181: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   dscores[y[i],i]  = dscores[y[i],i] - 1.0
# Backprop MaxPool3
# Backprop Relu5
# Backprop Conv5
# Backprop Relu4
# Backprop Conv4
# Backprop Relu3
# Backprop Conv3
# Backprop MaxPool2
# Backprop Relu2
# Backprop Conv2
# Backprop MaxPool1
# Backprop Relu1
# Backprop Conv1
# AlexNet Backward Pass Done
# (Iteration 1 / 20) loss: 6.907755
# TRAIN_ACC
# SOLVER check_accuracy
# AlexNet Forward Pass Done
# VAL_ACC
# SOLVER check_accuracy
# AlexNet Forward Pass Done
# AlexNet Forward Pass Done
# AlexNet Forward Pass Done
# AlexNet Forward Pass Done
# AlexNet Forward Pass Done
# AlexNet Forward Pass Done
# AlexNet Forward Pass Done
# AlexNet Forward Pass Done
# AlexNet Forward Pass Done
# AlexNet Forward Pass Done
# (Epoch 0 / 10) train acc: 0.000000; val_acc: 0.000000
# SOLVER _step
# AlexNet Forward Pass Done
# loss =  7.00258254437
# Backprop Affine3
# Backprop Affine2
# Backprop Affine1
# Backprop MaxPool3
# Backprop Relu5
# Backprop Conv5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-be5cab696b94> in <module>()
#      25                 },
#      26                 verbose=True, print_every=1)
# ---> 27 solver.train()
#
# C:/Users/Marks-M3800/Documents/A2/assignment2\cs231n\solver.py in train(self)
#     263
#     264     for t in range(int(num_iterations)):
# --> 265       self._step()
#     266
#     267       # Maybe print training loss
#
# C:/Users/Marks-M3800/Documents/A2/assignment2\cs231n\solver.py in _step(self)
#     177     #self.model.__init__()
#     178     #print('W1 shape = ', self.model.params['W1'].shape)
# --> 179     loss, grads = self.model.loss(X_batch, y_batch)
#     180     self.loss_history.append(loss)
#     181     #print('loss = ', loss)
#
# C:\Users\Marks-M3800\Documents\A_CNN_Model\alexnet.py in loss(self, X, y)
#     205                 #print('dx5_relu shape = ', dx5_relu.shape)
#     206                 print('Backprop Conv5')
# --> 207                 dx5,dW5,db5 = conv_backward_naive(dx5_relu, conv5_cache)
#     208                 #print('dx5 shape = ', dx5.shape)
#     209                 #print('dW5 shape = ', dW5.shape)
#
# C:/Users/Marks-M3800/Documents/A2/assignment2\cs231n\layers.py in conv_backward_naive(dout, cache)
#     597                  for k in range(int(OW)):
#     598                       w_start = k*stride
# --> 599                       dx[i,:,h_start:(h_start+HH),w_start:(w_start+WW)] += w[z,:,:,:]*dout[i,z,j,k]
#     600
#     601                       dw[z,:,:,:] += x_pad[i,:,h_start:(h_start+HH),w_start:(w_start+WW)]*dout[i,z,j,k]
#
# KeyboardInterrupt:

# %%
print(y_train.shape)
print(y_val.shape)
print(np.random.choice(num_train, 50))
# Out:
# (100,)
# (1000,)
# [79 47  2 40 77  5 93 60 74 56 61  2 57 40 90 98 92 29  9 52 55 72 47  4 81
#  47 88 34 88 55 46 58 79  9 59  6 48  6 83 33 98 64  1 58 28 70 97 49 68 80]
